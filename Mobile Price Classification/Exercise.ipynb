# %% [markdown]
# # Mobile Price Classification

# %% [markdown]
# ## Context
# Bob has started his own mobile company. He wants to give tough fight to big companies like Apple,Samsung etc.
#
# He does not know how to estimate price of mobiles his company creates. In this competitive mobile phone market you cannot simply assume things. To solve this problem he collects sales data of mobile phones of various companies.
#
# Bob wants to find out some relation between features of a mobile phone(eg:- RAM,Internal Memory etc) and its selling price. But he is not so good at Machine Learning. So he needs your help to solve this problem.
#
# In this problem you do not have to predict actual price but a price range indicating how high the price is
#
# - id           :ID
# - battery_power:Total energy a battery can store in one time measured in mAh
# - blue:Has bluetooth or not
# - clock_speed:speed at which microprocessor executes instructions
# - dual_sim:Has dual sim support or not
# - fc:Front Camera mega pixels
# - four_g:Has 4G or not
# - int_memory:Internal Memory in Gigabytes
# - m_dep:Mobile Depth in cm
# - mobile_wt:Weight of mobile phone
# - n_cores:Number of cores of processor
# - pc:Primary Camera mega pixels
# - px_height:Pixel Resolution Height
# - px_width:Pixel Resolution Width
# - ram:Random Access Memory in Megabytes
# - sc_h:Screen Height of mobile in cm
# - sc_w:Screen Width of mobile in cm
# - talk_time:longest time that a single battery charge will last when you are
# - three_g:Has 3G or not
# - touch_screen:Has touch screen or not
# - wifi:Has wifi or not

# %% [markdown]
# ## Use
# - This kind of prediction will help companies estimate price of mobiles to give tough competion to other mobile manufacturer
# - Also it will be usefull for Consumers to verify that they are paying best price for a mobile.
#
# ## Applied Models
# - MultiLayer-Perceptron Classifier
# - Decision Tree
# - K-Nearest Neighbors

# %%
# data preprocessing
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# model selection
from sklearn.model_selection import train_test_split

# classifier model
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load dataset

# %%
train = pd.read_csv('train.csv')
test  = pd.read_csv('test.csv')

# %% [markdown]
# ### Data exploration

# %%
train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
train.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  \
# 1995    0.8        106        6     ...            1222      1890   668    13
# 1996    0.2        187        4     ...             915      1965  2032    11
# 1997    0.7        108        8     ...             868      1632  3057     9
# 1998    0.1        145        5     ...             336       670   869    18
# 1999    0.9        168        6     ...             483       754  3919    19
#
# ...

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train.shape
# Out:
# (2000, 21)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
# battery_power    2000 non-null int64
# blue             2000 non-null int64
# clock_speed      2000 non-null float64
# dual_sim         2000 non-null int64
# fc               2000 non-null int64
# four_g           2000 non-null int64
# int_memory       2000 non-null int64
# m_dep            2000 non-null float64
# mobile_wt        2000 non-null int64
# n_cores          2000 non-null int64
# pc               2000 non-null int64
# px_height        2000 non-null int64
# px_width         2000 non-null int64
# ram              2000 non-null int64
# sc_h             2000 non-null int64
# sc_w             2000 non-null int64
# talk_time        2000 non-null int64
# three_g          2000 non-null int64
# touch_screen     2000 non-null int64
# wifi             2000 non-null int64
# price_range      2000 non-null int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
# check if there is a nan value.
train.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# Test data
test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...   pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...   16        226      1412  3476    12     7
# 1    0.8        191  ...   12        746       857  3895     6     0
# 2    0.9        186  ...    4       1270      1366  2396    17    10
# 3    0.5         96  ...   20        295      1752  3893    10     0
# 4    0.5        108  ...   18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test.tail()
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...   pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170  ...   17        644       913  2121    14     8
# 996    0.9        186  ...    2       1152      1632  1933     8     1
# 997    0.5         80  ...   12        477       825  1223     5     0
# 998    0.4        171  ...   12         38       832  2509    15    11
# 999    0.1        140  ...   19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
test.shape
# Out:
# (1000, 21)

# %%
test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
# fix index. column 'id' should be the index.
test.set_index('id', inplace=True)

# %%
test.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
#
#     mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id
# 1         193        3  16        226      1412  3476    12     7          2
# 2         191        5  12        746       857  3895     6     0          7
# 3         186        3   4       1270      1366  2396    17    10         10
# 4          96        8  20        295      1752  3893    10     0          7
# 5         108        6  18        749       810  1773    15     8          7
#
# ...

# %%
test.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# id
# 996            1700     1          1.9         0   0       1          54
# 997             609     0          1.8         1   0       0          13
# 998            1185     0          1.4         0   1       1           8
# 999            1533     1          0.5         1   0       0          50
# 1000           1270     1          0.5         0   4       1          35
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# id
# 996     0.5        170        7  17        644       913  2121    14     8
# 997     0.9        186        4   2       1152      1632  1933     8     1
# 998     0.5         80        1  12        477       825  1223     5     0
# 999     0.4        171        2  12         38       832  2509    15    11
# 1000    0.1        140        6  19        457       608  2828     9     2
#
#       talk_time  three_g  touch_screen  wifi
# id
# ...

# %%
train['battery_power'].corr(train['price_range'])
# Out:
# 0.20072261211373096

# %%
# get correlation
var_corr = train.corr()
var_corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %% [markdown]
# ### Correlation Coefficient
# https://www.investopedia.com/terms/c/correlationcoefficient.asp
# ### More about Heatmap & Correlation Coefficient
# https://www.datascience.com/blog/introduction-to-correlation-learn-data-science-tutorials
#
# ### visualize correlation

# %%
plt.figure(figsize=(16,16))
sns.heatmap(var_corr, 
            xticklabels=var_corr.columns, 
            yticklabels=var_corr.columns, 
            linewidths=0.1, 
            annot=True)

# %%
# scale data & see the difference.
scaled_train = MinMaxScaler().fit_transform(train)
scaled_train = pd.DataFrame(scaled_train,
                            index   = range(scaled_train.shape[0]),
                            columns = train.columns)
scaled_train.head()
# Out:
# c:\users\owner\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#    battery_power  blue  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0       0.227789   0.0         0.68       0.0  0.052632     0.0    0.080645
# 1       0.347361   1.0         0.00       1.0  0.000000     1.0    0.822581
# 2       0.041416   1.0         0.00       1.0  0.105263     1.0    0.629032
# 3       0.076152   1.0         0.80       0.0  0.000000     0.0    0.129032
# 4       0.881764   1.0         0.28       0.0  0.684211     1.0    0.677419
#
#       m_dep  mobile_wt   n_cores     ...       px_height  px_width       ram  \
# 0  0.555556   0.900000  0.142857     ...        0.010204  0.170895  0.612774
# 1  0.666667   0.466667  0.285714     ...        0.461735  0.993324  0.634687
# ...

# %%
scaled_train.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores     ...       px_height  \
# 1995    0.000000  0.777778   0.216667  0.714286     ...        0.623469
# 1996    0.596774  0.111111   0.891667  0.428571     ...        0.466837
# 1997    0.548387  0.666667   0.233333  1.000000     ...        0.442857
# 1998    0.709677  0.000000   0.541667  0.571429     ...        0.171429
# 1999    0.693548  0.888889   0.733333  0.714286     ...        0.246429
#
#       px_width       ram      sc_h      sc_w  talk_time  three_g  \
# ...

# %%
scaled_var_corr = scaled_train.corr()
scaled_var_corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(scaled_var_corr,
            xticklabels=scaled_var_corr.columns, 
            yticklabels=scaled_var_corr.columns, 
            linewidths=0.5, 
            annot=True, 
            vmin=-1,
            vmax=1)

# %%
scaled_train.plot(x='price_range', 
                  y='ram', 
                  style='o')

# %%
plt.scatter(scaled_train['price_range'].values, scaled_train['ram'].values)
plt.show()

# %%
train.plot(x='price_range', 
           y='ram', 
           style='o')

# %%
train.plot(x='ram', 
           y='price_range', 
           style='o')

# %% [markdown]
# ### Simple question.
# ## Should we remove features that have zero-correlation with the target ?
# to improve model accuracy.
#
# https://datascience.stackexchange.com/questions/40602/can-we-remove-features-that-have-zero-correlation-with-the-target-label
# ## Then what if all of features are not correlated with target ?

# %% [markdown]
# ## Classification

# %%
# split the target and the features.
X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1:]

# test dataframe already has no target so.
X_test = test

# %%
X_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y_train.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# ## Initialize Model Classifier

# %%
# Decision Tree classifier 
dt_model = DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ## Train Model

# %%
dt_model.fit(X_train.values, y_train.values)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
dt_predictions = dt_model.predict(X_test.values)
dt_predictions
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 1, 2, 0, 3, 2, 0, 2,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 1, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 0, 3, 3, 3, 0, 1, 1, 1,
#        2, 2, 1, 2, 1, 2, 2, 3, 3, 0, 2, 1, 2, 3, 1, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 0, 2, 1, 0, 2, 2, 3, 1, 0, 0, 3, 1, 2, 0, 1, 2, 3,
#        3, 2, 1, 3, 2, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 3, 3, 2, 0, 2,
#        1, 1, 3, 0, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 2, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 0, 0, 3, 0, 0, 0, 2, 0, 0, 2,
#        1, 0, 1, 2, 0, 0, 0, 1, 2, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 2, 1, 1, 3, 3, 3, 2, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 1, 2, 0, 3,
#        2, 2, 3, 0, 0, 1, 1, 3, 0, 1, 0, 2, 2, 1, 3, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 2, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 0, 2, 2, 1, 2,
#        3, 3, 3, 1, 1, 1, 2, 2, 2, 1, 3, 2, 0, 3, 0, 0, 2, 0, 0, 3, 2, 3,
# ...

# %%
X_test['price_range'] = dt_predictions
X_test.head(10)
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
# 6            1464     1          2.9         1   5       1          50    0.8
# 7            1718     0          2.4         0   1       0          47    1.0
# 8             833     0          2.4         1   0       0          62    0.8
# 9            1111     1          2.9         1   9       1          25    0.6
# 10           1520     0          0.5         0   1       0          25    0.5
#
#     mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# ...
